# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"E:\Machine-learning\Amoozeshgah-Tahlil-Dadeh\s4\Exercise\diabetes.csv")
df = pd.DataFrame(data)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
columns = df.columns.str.lower()
df.columns = columns
df
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      diabetespedigreefunction  age  outcome
# 0                       0.627   50        1
# ...

# %%
df.describe()
# Out:
#        pregnancies     glucose  bloodpressure  skinthickness     insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               bmi  diabetespedigreefunction         age     outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabates = df[df["outcome"] == 1]
diabates.count()
# Out:
# pregnancies                 268
# glucose                     268
# bloodpressure               268
# skinthickness               268
# insulin                     268
# bmi                         268
# diabetespedigreefunction    268
# age                         268
# outcome                     268
# dtype: int64

# %%
non_diabates = df[df["outcome"] == 0]
non_diabates.count()
# Out:
# pregnancies                 500
# glucose                     500
# bloodpressure               500
# skinthickness               500
# insulin                     500
# bmi                         500
# diabetespedigreefunction    500
# age                         500
# outcome                     500
# dtype: int64

# %%
x = np.arange(20,81,1)
mean_diabates = diabates["glucose"].mean()
mean_nondiabates = non_diabates["glucose"].mean()
mean_diabates =pd.Series([mean_diabates]*len(x))
mean_nondiabates = pd.Series([mean_nondiabates]*len(x))

# %%
plt.figure(figsize=(8,6), dpi=80)
plt.scatter(non_diabates["age"], non_diabates["glucose"], c="red", label="non_diabates")
plt.scatter(diabates["age"], diabates["glucose"], c="blue", label="diabates")
plt.plot(x, mean_nondiabates, linewidth=2, color="red", label="mean_nondiabates" )
plt.plot(x, mean_diabates, linewidth=2, color="blue", label="mean_diabates" )
plt.xlim(20,80)
plt.xlabel("Age", fontsize=10)
plt.ylabel("Glucose", fontsize=10)
plt.xticks(fontsize=10)
plt.legend(fontsize=10)

plt.show()

# %%
#The chart above depicts the levels of glucose in diabetic and non-diabetic patients according to age groups.
#Considering the figure, the average level of glucose in diabetic patients is higher than that in non-diabetic patients.
#The data points with a glucose level of 0 can be considered as suspicious or erroneous samples and can be excluded from further analyses.

# %%
fig, axs= plt.subplots(2,1, figsize=(8,8) )
axs[0].hist(diabates["glucose"], bins=20, color="blue", label="diabates")
axs[0].set_xlabel("glucose", fontsize=12)
axs[0].set_ylabel("Frequency", fontsize=12)
axs[0].set_ylim(0,40)
#axs[0].set_title("Diabates")
axs[0].legend(fontsize=12)

axs[1].hist(non_diabates["glucose"], bins=20, color="red", label="non diabates")
axs[1].set_xlabel("glucose", fontsize=12)
axs[1].set_ylabel("Frequency", fontsize=12)
axs[1].set_ylim(0,100)
#axs[1].set_title("Non Diabates")
axs[1].legend(fontsize=12)
fig.tight_layout()
#fig.legend()
#fig.set_figheight(6)
#fig.set_figwidth(6)

plt.show()

# %%
#The histogram above illustrates the frequency distribution of glucose levels in diabetic and non-diabetic patients. 
#While non-diabetic patients predominantly exhibit glucose levels between 90 to 120, diabetic patients show a majority distribution ranging from 100 to 190. 
#It's evident that glucose levels are higher in diabetic patients.

# %%
fig, axs= plt.subplots(2,1, figsize=(8,8) )
axs[0].hist(diabates["bmi"], bins=25, color="blue", label="diabates")
axs[0].set_xlabel("Bmi", fontsize=12)
axs[0].set_ylabel("Frequency", fontsize=12)
#axs[0].set_ylim(0,40)
#axs[0].set_title("Diabates")
axs[0].legend(fontsize=12)

axs[1].hist(non_diabates["bmi"], bins=25, color="red", label="non diabates")
axs[1].set_xlabel("Bmi", fontsize=12)
axs[1].set_ylabel("Frequency", fontsize=12)
#axs[1].set_ylim(0,100)
#axs[1].set_title("Non Diabates")
axs[1].legend(fontsize=12)
fig.tight_layout()
#fig.legend()
#fig.set_figheight(6)
#fig.set_figwidth(6)

plt.show()

# %%
print(diabates["bmi"].mean(), non_diabates["bmi"].mean())
# Out:
# 35.14253731343278 30.30419999999996

# %%
#The histogram above depicts the distribution of BMI (Body Mass Index) in diabetic and non-diabetic patients. 
#The average BMI in diabetic and non-diabetic patients is 35.1 and 30.3, respectively, indicating a higher BMI among diabetic patients. 
#Samples with a BMI of 0 can be considered suspicious and may be excluded from future analyses.

# %%
fig, axs= plt.subplots(2,1, figsize=(8,8) )
axs[0].boxplot(diabates["bloodpressure"], vert=False)
axs[0].set_xlabel("bloodpressure", fontsize=12)
axs[0].set_xlim(0,120)
axs[0].set_title("Diabates")
#axs[0].legend(fontsize=12)

axs[1].boxplot(non_diabates["bloodpressure"], vert=False)
axs[1].set_xlabel("bloodpressure", fontsize=12)
axs[1].set_xlim(0,120)
axs[1].set_title("Non Diabates")
#axs[1].legend(fontsize=12)
fig.tight_layout()
#fig.legend()
#fig.set_figheight(6)
#fig.set_figwidth(6)

plt.show()

# %%
#In the above plot, the distribution of blood pressure in diabetic and non-diabetic patients is represented using a box plot. 
#Data points beyond the whiskers can be considered as suspicious data and may warrant further investigation.

# %%
plt.figure(figsize=(8,6), dpi=80)
plt.scatter(non_diabates["insulin"], non_diabates["glucose"], c="red", label="non_diabates", alpha=0.7)
plt.scatter(diabates["insulin"], diabates["glucose"], c="blue", label="diabates", alpha=0.3)
#plt.xlim(20,80)
plt.xlabel("insulin", fontsize=10)
plt.ylabel("glucose", fontsize=10)
#plt.xticks(fontsize=10)
plt.legend(fontsize=10)

plt.show()

# %%
fig, axs= plt.subplots(2,1, figsize=(8,8) )
axs[0].boxplot(diabates["diabetespedigreefunction"], vert=False)
axs[0].set_xlabel("diabetespedigreefunction", fontsize=12)
#axs[0].set_xlim(0,120)
axs[0].set_title("Diabates")
#axs[0].legend(fontsize=12)

axs[1].boxplot(non_diabates["diabetespedigreefunction"], vert=False)
axs[1].set_xlabel("diabetespedigreefunction", fontsize=12)
#axs[1].set_xlim(0,120)
axs[1].set_title("Non Diabates")
#axs[1].legend(fontsize=12)
fig.tight_layout()
#fig.legend()
#fig.set_figheight(6)
#fig.set_figwidth(6)

plt.show()

# %%
fig, axs= plt.subplots(3,1, figsize=(8,8) )
axs[0].boxplot(diabates["age"], vert=False)
axs[0].set_xlabel("age", fontsize=12)
axs[0].set_xlim(20,80)
axs[0].set_title("Diabates")

axs[1].boxplot(non_diabates["age"], vert=False)
axs[1].set_xlabel("age", fontsize=12)
axs[1].set_xlim(20,80)
axs[1].set_title("Non Diabates")

axs[2].boxplot(df["age"], vert=False)
axs[2].set_xlabel("age", fontsize=12)
axs[2].set_xlim(20,80)
axs[2].set_title("Total")
fig.tight_layout()


plt.show()

# %%
print(df["age"].median())
print(diabates["age"].median())
print(non_diabates["age"].median())
# Out:
# 29.0
# 36.0
# 27.0

# %%
#In the above plot, the age distribution among all samples is compared with the age distribution among diabetic and non-diabetic patients. 
#The median age of all samples is 29 years, indicating that half of the total samples are below 29 years old and half are above 29 years old. 
#In the non-diabetic samples, the median age is 27, while in the diabetic samples, the median age is 36.
